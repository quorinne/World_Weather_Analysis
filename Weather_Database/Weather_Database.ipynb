# %%
# Import the requests library.
import requests
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit
from datetime import datetime
import random
import matplotlib.pyplot as plt

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.


# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
         
         # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | la ronge
# Processing Record 5 of Set 1 | luderitz
# Processing Record 6 of Set 1 | salalah
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | geraldton
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | lorengau
# Processing Record 13 of Set 1 | peruibe
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | makakilo city
# Processing Record 16 of Set 1 | hangu
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | yialos
# City not found. Skipping...
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | cabuyaro
# Processing Record 22 of Set 1 | dunedin
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | avera
# Processing Record 25 of Set 1 | finschhafen
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | sao gabriel da cachoeira
# Processing Record 28 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 1 | qaqortoq
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | tual
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 38 of Set 1 | ulundurpettai
# City not found. Skipping...
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | ponte nova
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | reconquista
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | hun
# Processing Record 46 of Set 1 | escarcega
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | santa cruz
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | ushuaia
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23268/77861631.py in <module>
#      25         set_count += 1
#      26         record_count = 1
# ---> 27         time.sleep(60)
#      28
#      29     # Create endpoint URL with each city.
#
# NameError: name 'time' is not defined

# %%
city_data
# Out:
# [{'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 77.47,
#   'Humidity': 80,
#   'Cloudiness': 67,
#   'Wind Speed': 8.32,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 71.76,
#   'Humidity': 48,
#   'Cloudiness': 67,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 80.4,
#   'Humidity': 77,
#   'Cloudiness': 46,
#   'Wind Speed': 13.33,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 46.65,
#   'Humidity': 34,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 71.11,
#   'Humidity': 60,
#   'Cloudiness': 63,
#   'Wind Speed': 6.44,
#   'Country': 'NA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 75.42,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 16.13,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.53,
#   'Humidity': 81,
#   'Cloudiness': 23,
#   'Wind Speed': 19.15,
#   'Country': 'KI',
#   'Current Description': 'light rain'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 70.21,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 75.25,
#   'Humidity': 83,
#   'Cloudiness': 6,
#   'Wind Speed': 10.74,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82.56,
#   'Humidity': 75,
#   'Cloudiness': 48,
#   'Wind Speed': 7.45,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Peruibe',
#   'Lat': -24.32,
#   'Lng': -46.9983,
#   'Max Temp': 80.96,
#   'Humidity': 90,
#   'Cloudiness': 83,
#   'Wind Speed': 4.92,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -17.7,
#   'Humidity': 90,
#   'Cloudiness': 9,
#   'Wind Speed': 8.72,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 80.01,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hangu',
#   'Lat': 39.2489,
#   'Lng': 117.7892,
#   'Max Temp': 26.64,
#   'Humidity': 91,
#   'Cloudiness': 42,
#   'Wind Speed': 4.9,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 84.25,
#   'Humidity': 70,
#   'Cloudiness': 8,
#   'Wind Speed': 6.91,
#   'Country': 'CK',
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 68.52,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -15,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 10.58,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabuyaro',
#   'Lat': 4.2817,
#   'Lng': -72.794,
#   'Max Temp': 92.37,
#   'Humidity': 39,
#   'Cloudiness': 73,
#   'Wind Speed': 11.88,
#   'Country': 'CO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 56.8,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 46.51,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 57.54,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'US',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Finschhafen',
#   'Lat': -6.6024,
#   'Lng': 147.8681,
#   'Max Temp': 81.25,
#   'Humidity': 79,
#   'Cloudiness': 33,
#   'Wind Speed': 5.93,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 19.54,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 17.54,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Gabriel Da Cachoeira',
#   'Lat': -0.1303,
#   'Lng': -67.0892,
#   'Max Temp': 82.04,
#   'Humidity': 71,
#   'Cloudiness': 98,
#   'Wind Speed': 1.34,
#   'Country': 'BR',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 12.58,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 6.08,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 42.96,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Country': 'TO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 84.16,
#   'Humidity': 70,
#   'Cloudiness': 67,
#   'Wind Speed': 4.38,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 64.78,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 17.49,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 54,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 62.06,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 0.67,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 84.16,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 49.95,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 9.31,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponte Nova',
#   'Lat': -20.4164,
#   'Lng': -42.9086,
#   'Max Temp': 75.79,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 70.12,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Reconquista',
#   'Lat': -29.15,
#   'Lng': -59.65,
#   'Max Temp': 69.89,
#   'Humidity': 63,
#   'Cloudiness': 91,
#   'Wind Speed': 15.1,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 55.47,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.32,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hun',
#   'Lat': 29.1268,
#   'Lng': 15.9477,
#   'Max Temp': 72.66,
#   'Humidity': 8,
#   'Cloudiness': 2,
#   'Wind Speed': 25.99,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'Escarcega',
#   'Lat': 18.6089,
#   'Lng': -90.7454,
#   'Max Temp': 99.01,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 10.33,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 6.4,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Cruz',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 91.45,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'BO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 69.22,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 40.66,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'}]

# %%
# Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Cidreira -30.1811  -50.2056     77.47        80          67        8.32
# 1      Albany  42.6001  -73.9662     71.76        48          67        1.01
# 2     Rikitea -23.1203 -134.9692     80.40        77          46       13.33
# 3    La Ronge  55.1001 -105.2842     46.65        34          20        8.05
# 4    Luderitz -26.6481   15.1594     71.11        60          63        6.44
# 5     Salalah  17.0151   54.0924     75.42        23           0       16.13
# 6  Butaritari   3.0707  172.7902     80.53        81          23       19.15
# 7   Geraldton -28.7667  114.6000     70.21        83          95       10.36
# 8    Saldanha -33.0117   17.9442     75.25        83           6       10.74
# 9    Lorengau  -2.0226  147.2712     82.56        75          48        7.45
#
#   Country Current Description
# 0      BR       broken clouds
# 1      US       broken clouds
# 2      PF    scattered clouds
# 3      CA          few clouds
# 4      NA       broken clouds
# 5      OM           clear sky
# 6      KI          light rain
# 7      AU     overcast clouds
# 8      ZA           clear sky
# 9      PG    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cidreira      BR -30.1811  -50.2056     77.47        80          67
# 1    Albany      US  42.6001  -73.9662     71.76        48          67
# 2   Rikitea      PF -23.1203 -134.9692     80.40        77          46
# 3  La Ronge      CA  55.1001 -105.2842     46.65        34          20
# 4  Luderitz      NA -26.6481   15.1594     71.11        60          63
#
#    Wind Speed Current Description
# 0        8.32       broken clouds
# 1        1.01       broken clouds
# 2       13.33    scattered clouds
# 3        8.05          few clouds
# 4        6.44       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
